# %% [markdown]
# # Step 7: The "Evidence Locker" (Visualization)
#
# ### Overview
# This notebook converts the raw CSV data into **publication-ready insights**. It answers the core engineering questions:
# 1.  **Who is smarter?** (Pass Rate by Agent)
# 2.  **Who is faster?** (Latency Distribution)
# 3.  **Is it worth the cost?** (Speed vs. Quality Trade-off)
# 4.  **Why did they fail?** (Failure Mode Analysis)
#
# ### The Dashboard
# The script below generates a 4-panel dashboard (`outputs/benchmark_dashboard.png`) that visualizes the "Logic Gap" between Local Models (Llama 3) and Cloud Models (Gemini).
#
# > **Note:** Ensure you have run `06_run_benchmark.ipynb` first to populate `leaderboard.csv`.

# %%
import sys
import os

# 1. Add project root to path
sys.path.append("..")

# 2. Magic command to ensure plots render inside the notebook
# %matplotlib inline

# 3. Import and Run
try:
    from src.visualize import generate_dashboard
    
    print("📊 Generating Dashboard...")
    generate_dashboard()
    
except ImportError:
    print("❌ Error: Could not import 'generate_dashboard'.") 
    print("Make sure you created the file 'src/visualize.py' as instructed.")
