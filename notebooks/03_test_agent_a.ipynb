# %%
# Import our new agent
import sys
sys.path.append("..") # Add root folder to path so we can import 'src'
from src.agents.base_agent import BaseAgent

# 1. Initialize
agent = BaseAgent(model_name="llama3.2:3b")

# 2. Give it a task that requires local data
task_prompt = "Who is the CTO of CyberDyne Systems? What is their email?"

# 3. Run and see the hallucination
response = agent.run(task_prompt)

print("-" * 50)
print("AGENT A RESPONSE:")
print(response)
print("-" * 50)
# Out:
# 🔌 Initializing Agent A (The Intern) with model: llama3.2:3b
# 🤖 Agent A is thinking about: Who is the CTO of CyberDyne Systems? What is their...
# --------------------------------------------------
# AGENT A RESPONSE:
# I do not have information on who the current CTO of Cyberdyne Systems is or their contact information, including an email address.
# --------------------------------------------------
